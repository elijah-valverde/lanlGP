# %% [markdown]
# # Particulate Matter at M1
# Here we overlay the PM2.5 concentration with environmental conditions {humidity, temperature, & pressure}

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pm_data_m1 = pd.read_csv(r"C:\Users\396760\lanl_data\PM_clean\ARMSAILM1_cleaned.csv")

# Convert timestamp to datetime
pm_data_m1['Time(UTC)'] = pd.to_datetime(pm_data_m1['Time(UTC)'])

# Set the timestamp as index
pm_data_m1.set_index('Time(UTC)', inplace=True)

# %%
# Plot Relative Humidity with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(pm_data_m1.index, pm_data_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Relative Humidity (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(pm_data_m1.index, pm_data_m1['sample_rh_pct'], color=color, label='Relative Humidity', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('PM2.5 Concentration and Relative Humidity Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot Temperature with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(pm_data_m1.index, pm_data_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Temperature (°C)', color=color)  # we already handled the x-label with ax1
ax2.plot(pm_data_m1.index, pm_data_m1['sample_temp_C'], color=color, label='Temperature', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('PM2.5 Concentration and Temperature Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot Pressure with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(pm_data_m1.index, pm_data_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:purple'
ax2.set_ylabel('Pressure (mmHg)', color=color)  # we already handled the x-label with ax1
ax2.plot(pm_data_m1.index, pm_data_m1['sample_pres_mmHg'], color=color, label='Pressure', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

# Set secondary y-axis range and ticks
ax2.set_ylim(0, 1000)
ax2.set_yticks(range(0, 1001, 125))

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('PM2.5 Concentration and Pressure Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %% [markdown]
# # Daily average

# %%
# Calculate daily averages
daily_avg_m1 = pm_data_m1.resample('D').mean()

# Plot daily average Relative Humidity with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(daily_avg_m1.index, daily_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Relative Humidity (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(daily_avg_m1.index, daily_avg_m1['sample_rh_pct'], color=color, label='Relative Humidity', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Daily Average PM2.5 Concentration and Relative Humidity Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot daily average Temperature with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(daily_avg_m1.index, daily_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Temperature (°C)', color=color)  # we already handled the x-label with ax1
ax2.plot(daily_avg_m1.index, daily_avg_m1['sample_temp_C'], color=color, label='Temperature', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Daily Average PM2.5 Concentration and Temperature Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot daily average Pressure with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(daily_avg_m1.index, daily_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:purple'
ax2.set_ylabel('Pressure (mmHg)', color=color)  # we already handled the x-label with ax1
ax2.plot(daily_avg_m1.index, daily_avg_m1['sample_pres_mmHg'], color=color, label='Pressure', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

# Set secondary y-axis range and ticks
ax2.set_ylim(0, 1000)
ax2.set_yticks(range(0, 1001, 125))

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Daily Average PM2.5 Concentration and Pressure Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %% [markdown]
# # Hourly Average

# %%
# Calculate hourly averages
hourly_avg_m1 = pm_data_m1.resample('H').mean()

# Plot hourly average Relative Humidity with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(hourly_avg_m1.index, hourly_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Relative Humidity (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(hourly_avg_m1.index, hourly_avg_m1['sample_rh_pct'], color=color, label='Relative Humidity', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Hourly Average PM2.5 Concentration and Relative Humidity Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()
# Out:
# C:\Users\396760\AppData\Local\Temp\ipykernel_14840\4075902487.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly_avg_m1 = pm_data_m1.resample('H').mean()

# %%
# Plot hourly average Temperature with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(hourly_avg_m1.index, hourly_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Temperature (°C)', color=color)  # we already handled the x-label with ax1
ax2.plot(hourly_avg_m1.index, hourly_avg_m1['sample_temp_C'], color=color, label='Temperature', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Hourly Average PM2.5 Concentration and Temperature Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot hourly average Pressure with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(hourly_avg_m1.index, hourly_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:purple'
ax2.set_ylabel('Pressure (mmHg)', color=color)  # we already handled the x-label with ax1
ax2.plot(hourly_avg_m1.index, hourly_avg_m1['sample_pres_mmHg'], color=color, label='Pressure', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

# Set secondary y-axis range and ticks
ax2.set_ylim(0, 1000)
ax2.set_yticks(range(0, 1001, 125))

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Hourly Average PM2.5 Concentration and Pressure Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %% [markdown]
# # Ten Minute Average

# %%
# Calculate ten-minute averages
ten_min_avg_m1 = pm_data_m1.resample('10T').mean()

# Plot ten-minute average Relative Humidity with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(ten_min_avg_m1.index, ten_min_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
ax2.set_ylabel('Relative Humidity (%)', color=color)  # we already handled the x-label with ax1
ax2.plot(ten_min_avg_m1.index, ten_min_avg_m1['sample_rh_pct'], color=color, label='Relative Humidity', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Ten-Minute Average PM2.5 Concentration and Relative Humidity Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()
# Out:
# C:\Users\396760\AppData\Local\Temp\ipykernel_14840\1974985180.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   ten_min_avg_m1 = pm_data_m1.resample('10T').mean()

# %%
# Plot ten-minute average Temperature with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(ten_min_avg_m1.index, ten_min_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:red'
ax2.set_ylabel('Temperature (°C)', color=color)  # we already handled the x-label with ax1
ax2.plot(ten_min_avg_m1.index, ten_min_avg_m1['sample_temp_C'], color=color, label='Temperature', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Ten-Minute Average PM2.5 Concentration and Temperature Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()

# %%
# Plot ten-minute average Pressure with PM2.5 concentration
fig, ax1 = plt.subplots(figsize=(15, 7))

color = 'tab:blue'
ax1.set_xlabel('Time')
ax1.set_ylabel('PM2.5 Concentration (µg/m³)', color=color)
ax1.plot(ten_min_avg_m1.index, ten_min_avg_m1['pm_25_ug_per_m3'], color=color, label='PM2.5')
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:purple'
ax2.set_ylabel('Pressure (mmHg)', color=color)  # we already handled the x-label with ax1
ax2.plot(ten_min_avg_m1.index, ten_min_avg_m1['sample_pres_mmHg'], color=color, label='Pressure', alpha=0.6)
ax2.tick_params(axis='y', labelcolor=color)

# Set secondary y-axis range and ticks
ax2.set_ylim(0, 1000)
ax2.set_yticks(range(0, 1001, 125))

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Ten-Minute Average PM2.5 Concentration and Pressure Over Time (M1)')
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)
plt.grid(True)
plt.show()
